# %% [markdown]
# # CERA 2019 presentation: Python for Analyzing and Visualizing Education Data
# #### 45-min presentation at CERA 2019 on using python for ananalyzing and visualizing education data. First half will illustrate a typical data analysis workflow and the second part will be sharing resources for further learning.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     The goal of this notebook is to provide an example of a typical data analysis workflow.
#     <ul>
#         <li> measurable goals for this notebook </li>
#         <li> Identify <i>variables of interest in dataset. </li>
#         <li> Clean the dataset and create an analytical file.</li>
#         <li> Create effective data visualizations illustrating some of the findings </li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     We've downloaded raw data from <strong><i>IPEDS</i></strong> and are now in the process of creating an analytical mastefile.
# </details>

# %% [markdown]
# ***

# %% [markdown]
# Preparing your working environment:
# 1. `pandas`: data analysis library.
# 2. `zipfile`: let's you work with zipped files.
# 3. `pathlib`: allows you to create _filepath_ objects so you can navigate the file system regardless of the operating system (i.e. using forward slashes vs back slashes)
# 4. `tools`: is a python script in the same working directory. You can write your functions separately from this notebooks and **import** them as needed. This will keep your notebook clean.
# 5. `datetime`: to create a date stamp. more powerful version control systems like `git` would be better but at least _tagging_ your files with a date can help you keep different versions.

# %%
import pandas as pd
from zipfile import ZipFile
from pathlib import Path
from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '18-Nov-19'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
EXTERNAL_DATA = Path("../data/external/")
FINAL_DATA = Path("../data/final/")

# %%
tree(RAW_DATA)
# Out:
# + ..\data\raw
#     + 11-18-2019---387.zip

# %% [markdown]
# # Reading in data

# %% [markdown]
# We can use `ZipFile` to manipulate our zipped raw data in this environment.

# %%
file = ZipFile(RAW_DATA / '11-18-2019---387.zip')

# %%
file.filelist
# Out:
# [<ZipInfo filename='Data_11-18-2019---387.csv' compress_type=deflate external_attr=0x20 file_size=66990 compress_size=17514>,
#  <ZipInfo filename='ValueLabels_11-18-2019---387.csv' compress_type=deflate external_attr=0x20 file_size=2457 compress_size=521>]

# %% [markdown]
# There's two `csv` files in there, we'll read each of them into their own `DataFrame`. The `DataFrame` is the primary data structure in `pandas`.
#
# > Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns. <br>
# \- _GeeksforGeeks.org_

# %%
data = pd.read_csv(file.open("Data_11-18-2019---387.csv"))
labels = pd.read_csv(file.open("ValueLabels_11-18-2019---387.csv"))

# %%
data.head()
# Out:
#    UnitID                        Institution Name  \
# 0  491464                        ABC Adult School
# 1  493105        ABC Adult School - Cabrillo Lane
# 2  485500                         ABCO Technology
# 3  488031              Abraham Lincoln University
# 4  457271  Academy for Jewish Religion-California
#
#    Sector of institution (HD2018)  Level of institution (HD2018)  \
# 0                               7                              3
# 1                              99                             -3
# 2                               9                              3
# 3                               3                              1
# 4                               2                              1
#
#    Control of institution (HD2018)  Degree-granting status (HD2018)  \
# 0                                1                                2
# 1                               -3                               -3
# 2                                3                                2
# 3                                3                                1
# 4                                2                                1
#
#    Degree of urbanization (Urban-centric locale) (HD2018)  \
# 0                                                 21
# 1                                                 21
# 2                                                 21
# 3                                                 12
# 4                                                 11
#
#    Tribal college (HD2018)  Historically Black College or University (HD2018)  \
# 0                        2                                                  2
# 1                        2                                                  2
# 2                        2                                                  2
# 3                        2                                                  2
# 4                        2                                                  2
#
#    Graduation rate  total cohort (DRVGR2017_RV)  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#    Graduation rate - Bachelor degree within 6 years  Asian/Native Hawaiian/Pacific Islander (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Asian (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Black  non-Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  White  non-Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  two or more races (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Race/ethnicity unknown (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Nonresident alien (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 36
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 37 columns]

# %%
labels
# Out:
#                                          VariableName  Value  \
# 0                      Sector of institution (HD2018)      0
# 1                      Sector of institution (HD2018)      1
# 2                      Sector of institution (HD2018)      2
# 3                      Sector of institution (HD2018)      3
# 4                      Sector of institution (HD2018)      4
# 5                      Sector of institution (HD2018)      5
# 6                      Sector of institution (HD2018)      6
# 7                      Sector of institution (HD2018)      7
# 8                      Sector of institution (HD2018)      8
# 9                      Sector of institution (HD2018)      9
# 10                     Sector of institution (HD2018)     99
# 11                      Level of institution (HD2018)      1
# 12                      Level of institution (HD2018)      2
# 13                      Level of institution (HD2018)      3
# 14                      Level of institution (HD2018)     -3
# 15                    Control of institution (HD2018)      1
# 16                    Control of institution (HD2018)      2
# 17                    Control of institution (HD2018)      3
# 18                    Control of institution (HD2018)     -3
# 19                    Degree-granting status (HD2018)      1
# 20                    Degree-granting status (HD2018)      2
# 21                    Degree-granting status (HD2018)     -3
# 22  Historically Black College or University (HD2018)      2
# 23                            Tribal college (HD2018)      2
# 24  Degree of urbanization (Urban-centric locale) ...     11
# 25  Degree of urbanization (Urban-centric locale) ...     12
# 26  Degree of urbanization (Urban-centric locale) ...     13
# 27  Degree of urbanization (Urban-centric locale) ...     21
# 28  Degree of urbanization (Urban-centric locale) ...     22
# 29  Degree of urbanization (Urban-centric locale) ...     23
# 30  Degree of urbanization (Urban-centric locale) ...     31
# 31  Degree of urbanization (Urban-centric locale) ...     32
# 32  Degree of urbanization (Urban-centric locale) ...     33
# 33  Degree of urbanization (Urban-centric locale) ...     41
# 34  Degree of urbanization (Urban-centric locale) ...     42
#
#                                      ValueLabel
# 0                           Administrative Unit
# 1                       Public, 4-year or above
# 2       Private not-for-profit, 4-year or above
# 3           Private for-profit, 4-year or above
# 4                                Public, 2-year
# 5                Private not-for-profit, 2-year
# 6                    Private for-profit, 2-year
# 7                      Public, less-than 2-year
# 8      Private not-for-profit, less-than 2-year
# 9          Private for-profit, less-than 2-year
# 10                  Sector unknown (not active)
# 11                           Four or more years
# 12             At least 2 but less than 4 years
# 13          Less than 2 years (below associate)
# 14                              {Not available}
# 15                                       Public
# 16                       Private not-for-profit
# 17                           Private for-profit
# 18                              {Not available}
# 19                              Degree-granting
# 20  Nondegree-granting, primarily postsecondary
# 21                              {Not available}
# 22                                           No
# 23                                           No
# 24                                  City: Large
# 25                                City: Midsize
# 26                                  City: Small
# 27                                Suburb: Large
# 28                              Suburb: Midsize
# 29                                Suburb: Small
# 30                                 Town: Fringe
# 31                                Town: Distant
# 32                                 Town: Remote
# 33                                Rural: Fringe
# 34                               Rural: Distant

# %% [markdown]
# # Exploring data

# %% [markdown]
# `Pandas` is designed for data analysis so it comes with lots of useful functions to explore your data

# %%
data.describe()
# Out:
#               UnitID  Sector of institution (HD2018)  \
# count     663.000000                      663.000000
# mean   276188.506787                        5.600302
# std    168159.927854                        9.418042
# min    108232.000000                        0.000000
# 25%    117242.500000                        2.000000
# 50%    125499.000000                        4.000000
# 75%    454798.000000                        9.000000
# max    493442.000000                       99.000000
#
#        Level of institution (HD2018)  Control of institution (HD2018)  \
# count                     663.000000                       663.000000
# mean                        1.844646                         2.138763
# std                         0.948045                         0.976486
# min                        -3.000000                        -3.000000
# 25%                         1.000000                         1.000000
# 50%                         2.000000                         2.000000
# 75%                         3.000000                         3.000000
# max                         3.000000                         3.000000
#
#        Degree-granting status (HD2018)  \
# count                       663.000000
# mean                          1.288084
# std                           0.621828
# min                          -3.000000
# 25%                           1.000000
# 50%                           1.000000
# 75%                           2.000000
# max                           2.000000
#
#        Degree of urbanization (Urban-centric locale) (HD2018)  \
# count                                         663.000000
# mean                                           16.514329
# std                                             7.000606
# min                                            11.000000
# 25%                                            11.000000
# 50%                                            13.000000
# 75%                                            21.000000
# max                                            42.000000
#
#        Tribal college (HD2018)  \
# count                    663.0
# mean                       2.0
# std                        0.0
# min                        2.0
# 25%                        2.0
# 50%                        2.0
# 75%                        2.0
# max                        2.0
#
#        Historically Black College or University (HD2018)  \
# count                                              663.0
# mean                                                 2.0
# std                                                  0.0
# min                                                  2.0
# 25%                                                  2.0
# 50%                                                  2.0
# 75%                                                  2.0
# max                                                  2.0
#
#        Graduation rate  total cohort (DRVGR2017_RV)  \
# count                                    510.000000
# mean                                      58.817647
# std                                       23.943944
# min                                        0.000000
# 25%                                       37.000000
# 50%                                       64.000000
# 75%                                       77.000000
# max                                      100.000000
#
#        Graduation rate  men (DRVGR2017_RV)  ...  \
# count                           333.000000  ...
# mean                             48.264264  ...
# std                              24.547148  ...
# min                               0.000000  ...
# 25%                              27.000000  ...
# 50%                              46.000000  ...
# 75%                              66.000000  ...
# max                             100.000000  ...
#
#        Graduation rate - Bachelor degree within 6 years  Asian/Native Hawaiian/Pacific Islander (DRVGR2017_RV)  \
# count                                         118.000000
# mean                                           66.406780
# std                                            26.694613
# min                                             0.000000
# 25%                                            51.000000
# 50%                                            70.000000
# 75%                                            87.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Asian (DRVGR2017_RV)  \
# count                                         116.000000
# mean                                           66.456897
# std                                            26.637793
# min                                             0.000000
# 25%                                            50.750000
# 50%                                            69.500000
# 75%                                            88.250000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)  \
# count                                          84.000000
# mean                                           58.321429
# std                                            34.770906
# min                                             0.000000
# 25%                                            32.250000
# 50%                                            57.000000
# 75%                                           100.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Black  non-Hispanic (DRVGR2017_RV)  \
# count                                         111.000000
# mean                                           49.144144
# std                                            29.279173
# min                                             0.000000
# 25%                                            30.000000
# 50%                                            50.000000
# 75%                                            71.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Hispanic (DRVGR2017_RV)  \
# count                                         124.000000
# mean                                           56.572581
# std                                            25.952168
# min                                             0.000000
# 25%                                            42.000000
# 50%                                            56.500000
# 75%                                            76.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  White  non-Hispanic (DRVGR2017_RV)  \
# count                                         125.000000
# mean                                           61.208000
# std                                            23.797972
# min                                             0.000000
# 25%                                            46.000000
# 50%                                            64.000000
# 75%                                            79.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  two or more races (DRVGR2017_RV)  \
# count                                         103.000000
# mean                                           59.310680
# std                                            26.414505
# min                                             0.000000
# 25%                                            46.000000
# 50%                                            60.000000
# 75%                                            79.500000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Race/ethnicity unknown (DRVGR2017_RV)  \
# count                                         101.000000
# mean                                           59.257426
# std                                            27.073106
# min                                             0.000000
# 25%                                            42.000000
# 50%                                            64.000000
# 75%                                            80.000000
# max                                           100.000000
#
#        Graduation rate - Bachelor degree within 6 years  Nonresident alien (DRVGR2017_RV)  \
# count                                         102.000000
# mean                                           57.568627
# std                                            29.070931
# min                                             0.000000
# 25%                                            40.750000
# 50%                                            58.500000
# 75%                                            81.000000
# max                                           100.000000
#
#        Unnamed: 36
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 36 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 37 columns):
# UnitID                                                                                                        663 non-null int64
# Institution Name                                                                                              663 non-null object
# Sector of institution (HD2018)                                                                                663 non-null int64
# Level of institution (HD2018)                                                                                 663 non-null int64
# Control of institution (HD2018)                                                                               663 non-null int64
# Degree-granting status (HD2018)                                                                               663 non-null int64
# Degree of urbanization (Urban-centric locale) (HD2018)                                                        663 non-null int64
# Tribal college (HD2018)                                                                                       663 non-null int64
# Historically Black College or University (HD2018)                                                             663 non-null int64
# Graduation rate  total cohort (DRVGR2017_RV)                                                                  510 non-null float64
# Graduation rate  men (DRVGR2017_RV)                                                                           333 non-null float64
# Graduation rate  women (DRVGR2017_RV)                                                                         335 non-null float64
# Graduation rate  American Indian or Alaska Native (DRVGR2017_RV)                                              210 non-null float64
# Graduation rate  Asian/Native Hawaiian/Other Pacific Islander (DRVGR2017_RV)                                  319 non-null float64
# Graduation rate  Asian (DRVGR2017_RV)                                                                         313 non-null float64
# Graduation rate  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)                                     240 non-null float64
# Graduation rate  Black  non-Hispanic (DRVGR2017_RV)                                                           310 non-null float64
# Graduation rate  Hispanic (DRVGR2017_RV)                                                                      325 non-null float64
# Graduation rate  White  non-Hispanic (DRVGR2017_RV)                                                           327 non-null float64
# Graduation rate  Nonresident alien (DRVGR2017_RV)                                                             222 non-null float64
# Graduation rate  Race/ethnicity unknown (DRVGR2017_RV)                                                        267 non-null float64
# Graduation rate  two or more races (DRVGR2017_RV)                                                             272 non-null float64
# Graduation rate - Bachelor degree within 4 years  total (DRVGR2017_RV)                                        135 non-null float64
# Graduation rate - Bachelor degree within 6 years  total (DRVGR2017_RV)                                        135 non-null float64
# Graduation rate - Bachelor degree within 6 years  men (DRVGR2017_RV)                                          131 non-null float64
# Graduation rate - Bachelor degree within 6 years  women (DRVGR2017_RV)                                        132 non-null float64
# Graduation rate - Bachelor degree within 6 years  American Indian or Alaska Native (DRVGR2017_RV)             75 non-null float64
# Graduation rate - Bachelor degree within 6 years  Asian/Native Hawaiian/Pacific Islander (DRVGR2017_RV)       118 non-null float64
# Graduation rate - Bachelor degree within 6 years  Asian (DRVGR2017_RV)                                        116 non-null float64
# Graduation rate - Bachelor degree within 6 years  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)    84 non-null float64
# Graduation rate - Bachelor degree within 6 years  Black  non-Hispanic (DRVGR2017_RV)                          111 non-null float64
# Graduation rate - Bachelor degree within 6 years  Hispanic (DRVGR2017_RV)                                     124 non-null float64
# Graduation rate - Bachelor degree within 6 years  White  non-Hispanic (DRVGR2017_RV)                          125 non-null float64
# Graduation rate - Bachelor degree within 6 years  two or more races (DRVGR2017_RV)                            103 non-null float64
# Graduation rate - Bachelor degree within 6 years  Race/ethnicity unknown (DRVGR2017_RV)                       101 non-null float64
# Graduation rate - Bachelor degree within 6 years  Nonresident alien (DRVGR2017_RV)                            102 non-null float64
# Unnamed: 36                                                                                                   0 non-null float64
# dtypes: float64(28), int64(8), object(1)
# memory usage: 191.8+ KB

# %%
data.shape
# Out:
# (663, 37)

# %% [markdown]
# ### Drop a column

# %% [markdown]
# It varies, but most of the time `pandas` methods and functions are _intuitive_.
#
# _I need to drop this column from a DataFrame so I "tell" the dataframe "drop" and pass the name of the column to it's "columns" argument._

# %%
data.drop(columns = 'Unnamed: 36')
# Out:
#      UnitID                                   Institution Name  \
# 0    491464                                   ABC Adult School
# 1    493105                   ABC Adult School - Cabrillo Lane
# 2    485500                                    ABCO Technology
# 3    488031                         Abraham Lincoln University
# 4    457271             Academy for Jewish Religion-California
# ..      ...                                                ...
# 658  126076  Yeshiva Ohr Elchonon Chabad West Coast Talmudi...
# 659  401250  Yo San University of Traditional Chinese Medicine
# 660  126100         Yosemite Community College District Office
# 661  126119                                       Yuba College
# 662  486248                                    ZMS The Academy
#
#      Sector of institution (HD2018)  Level of institution (HD2018)  \
# 0                                 7                              3
# 1                                99                             -3
# 2                                 9                              3
# 3                                 3                              1
# 4                                 2                              1
# ..                              ...                            ...
# 658                               2                              1
# 659                               2                              1
# 660                               0                              1
# 661                               4                              2
# 662                               9                              3
#
#      Control of institution (HD2018)  Degree-granting status (HD2018)  \
# 0                                  1                                2
# 1                                 -3                               -3
# 2                                  3                                2
# 3                                  3                                1
# 4                                  2                                1
# ..                               ...                              ...
# 658                                2                                1
# 659                                2                                1
# 660                                1                                1
# 661                                1                                1
# 662                                3                                2
#
#      Degree of urbanization (Urban-centric locale) (HD2018)  \
# 0                                                   21
# 1                                                   21
# 2                                                   21
# 3                                                   12
# 4                                                   11
# ..                                                 ...
# 658                                                 11
# 659                                                 21
# 660                                                 12
# 661                                                 22
# 662                                                 11
#
#      Tribal college (HD2018)  \
# 0                          2
# 1                          2
# 2                          2
# 3                          2
# 4                          2
# ..                       ...
# 658                        2
# 659                        2
# 660                        2
# 661                        2
# 662                        2
#
#      Historically Black College or University (HD2018)  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 658                                                  2
# 659                                                  2
# 660                                                  2
# 661                                                  2
# 662                                                  2
#
#      Graduation rate  total cohort (DRVGR2017_RV)  ...  \
# 0                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# ..                                            ...  ...
# 658                                          32.0  ...
# 659                                           NaN  ...
# 660                                           NaN  ...
# 661                                          23.0  ...
# 662                                          43.0  ...
#
#      Graduation rate - Bachelor degree within 6 years  American Indian or Alaska Native (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Asian/Native Hawaiian/Pacific Islander (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Asian (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Black  non-Hispanic (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Hispanic (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  White  non-Hispanic (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                               38.0
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  two or more races (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Race/ethnicity unknown (DRVGR2017_RV)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
#      Graduation rate - Bachelor degree within 6 years  Nonresident alien (DRVGR2017_RV)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 658                                                0.0
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
#
# [663 rows x 36 columns]

# %%
data = data.drop(columns = 'Unnamed: 36')

# %% [markdown]
# # Adding labels to your data

# %% [markdown]
# We have a **data** `DataFrame` and a **value labels** `DataFrame` and what we want is to have those two in one.

# %%
value_labels = {}
for variable_name in labels['VariableName'].unique():
    # make a subset of the dataframe which contains only that variable
    working_df = labels[labels['VariableName'] == variable_name]
    # start a blank dictionary for each variable name
    value_labels[variable_name] = {}
    for (index, value_label) in working_df[['Value', 'ValueLabel']].iterrows():
        # iterate over each value - label and add them to the current dictionary
        value_labels[variable_name][value_label[0]] = value_label[1]

# %%
value_labels
# Out:
# {'Sector of institution (HD2018)': {0: 'Administrative Unit',
#   1: 'Public, 4-year or above',
#   2: 'Private not-for-profit, 4-year or above',
#   3: 'Private for-profit, 4-year or above',
#   4: 'Public, 2-year',
#   5: 'Private not-for-profit, 2-year',
#   6: 'Private for-profit, 2-year',
#   7: 'Public, less-than 2-year',
#   8: 'Private not-for-profit, less-than 2-year',
#   9: 'Private for-profit, less-than 2-year',
#   99: 'Sector unknown (not active)'},
#  'Level of institution (HD2018)': {1: 'Four or more years',
#   2: 'At least 2 but less than 4 years',
#   3: 'Less than 2 years (below associate)',
#   -3: '{Not available}'},
#  'Control of institution (HD2018)': {1: 'Public',
#   2: 'Private not-for-profit',
#   3: 'Private for-profit',
#   -3: '{Not available}'},
#  'Degree-granting status (HD2018)': {1: 'Degree-granting',
#   2: 'Nondegree-granting, primarily postsecondary',
#   -3: '{Not available}'},
#  'Historically Black College or University (HD2018)': {2: 'No'},
#  'Tribal college (HD2018)': {2: 'No'},
#  'Degree of urbanization (Urban-centric locale) (HD2018)': {11: 'City: Large',
#   12: 'City: Midsize',
#   13: 'City: Small',
#   21: 'Suburb: Large',
#   22: 'Suburb: Midsize',
#   23: 'Suburb: Small',
#   31: 'Town: Fringe',
#   32: 'Town: Distant',
#   33: 'Town: Remote',
#   41: 'Rural: Fringe',
#   42: 'Rural: Distant'}}

# %%
for key in value_labels.keys():
    data[key] = data[key].map(value_labels[key])

# %%
data.head()
# Out:
#    UnitID                        Institution Name  \
# 0  491464                        ABC Adult School
# 1  493105        ABC Adult School - Cabrillo Lane
# 2  485500                         ABCO Technology
# 3  488031              Abraham Lincoln University
# 4  457271  Academy for Jewish Religion-California
#
#             Sector of institution (HD2018)  \
# 0                 Public, less-than 2-year
# 1              Sector unknown (not active)
# 2     Private for-profit, less-than 2-year
# 3      Private for-profit, 4-year or above
# 4  Private not-for-profit, 4-year or above
#
#          Level of institution (HD2018) Control of institution (HD2018)  \
# 0  Less than 2 years (below associate)                          Public
# 1                      {Not available}                 {Not available}
# 2  Less than 2 years (below associate)              Private for-profit
# 3                   Four or more years              Private for-profit
# 4                   Four or more years          Private not-for-profit
#
#                Degree-granting status (HD2018)  \
# 0  Nondegree-granting, primarily postsecondary
# 1                              {Not available}
# 2  Nondegree-granting, primarily postsecondary
# 3                              Degree-granting
# 4                              Degree-granting
#
#   Degree of urbanization (Urban-centric locale) (HD2018)  \
# 0                                      Suburb: Large
# 1                                      Suburb: Large
# 2                                      Suburb: Large
# 3                                      City: Midsize
# 4                                        City: Large
#
#   Tribal college (HD2018) Historically Black College or University (HD2018)  \
# 0                      No                                                No
# 1                      No                                                No
# 2                      No                                                No
# 3                      No                                                No
# 4                      No                                                No
#
#    Graduation rate  total cohort (DRVGR2017_RV)  ...  \
# 0                                           NaN  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#    Graduation rate - Bachelor degree within 6 years  American Indian or Alaska Native (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Asian/Native Hawaiian/Pacific Islander (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Asian (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Native Hawaiian or Other Pacific Islander (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Black  non-Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  White  non-Hispanic (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  two or more races (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Race/ethnicity unknown (DRVGR2017_RV)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Graduation rate - Bachelor degree within 6 years  Nonresident alien (DRVGR2017_RV)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# # Filtering data

# %%
mask_sector = data['Sector of institution (HD2018)'] != 'Sector unknown (not active)'
mask_level = data['Level of institution (HD2018)'] != '{Not available}'
mask_control = data['Control of institution (HD2018)'] != '{Not available}'
mask_degree = data['Degree-granting status (HD2018)'] != '{Not available}'

# %%
data.shape
# Out:
# (663, 36)

# %%
data[mask_sector].shape
# Out:
# (657, 36)

# %%
data[mask_level].shape
# Out:
# (657, 36)

# %%
data[mask_control].shape
# Out:
# (657, 36)

# %%
data[mask_degree].shape
# Out:
# (657, 36)

# %%
data[mask_sector & mask_level & mask_control & mask_degree].shape
# Out:
# (657, 36)

# %%
data = data[mask_sector & mask_level & mask_control & mask_degree]

# %%
data.shape
# Out:
# (657, 36)

# %% [markdown]
# # Saving your work

# %%
data.to_csv(INTERIM_DATA / f'processed-data-{today}.csv', index = False)

# %%
data.to_excel(INTERIM_DATA / f'processed-data-{today}.xlsx', index = False)
